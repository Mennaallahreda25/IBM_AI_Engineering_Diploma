# %% [markdown]
# <a href="http://cocl.us/pytorch_link_top">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/Pytochtop.png" width="750" alt="IBM Product ">
# </a>

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0321EN-SkillsNetwork/image/IDSN-logo.png" width="200" alt="cognitiveclass.ai logo">

# %% [markdown]
# <h1>Objective</h1><ul><li> How to create a dataset object.</li></ul>

# %% [markdown]
# <h1>Data Preparation with PyTorch</h1>

# %% [markdown]
# <p>Crack detection has vital importance for structural health monitoring and inspection. We would like to train a network to detect Cracks, we will denote the images that contain cracks as positive and images with no cracks as negative.  In this lab you are going to have to build a dataset object. There are five questions in this lab, Including some questions that are intermediate steps to help you build the dataset object. You are going to have to remember the output for some  of the questions. </p>

# %% [markdown]
# <h2>Table of Contents</h2>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
#
# <ul>
#     <li><a href="#auxiliary"> Imports and Auxiliary Functions </a></li>
#     <li><a href="#download_data"> Download data</a></li>
#     <li><a href="#examine_files">Examine Files</a></li>
#     <li><a href="#Question_1"><b>Question 1:find number of files</b> </a></li>
#     <li><a href="#assign_labels">Assign Labels to Images  </a></li>
#     <li><a href="#Question_2"><b>Question 2 : Assign labels to image </b> </a></li>
#     <li><a href="#split">Training  and Validation  Split </a></li>
#     <li><a href="#Question_3"><b>Question 3: Training  and Validation  Split</b> </a></li>
# <li><a href="#data_class">Create a Dataset Class </a></li>
#     <li><a href="#Question_4"><b>Question 4:Display  training dataset object</b> </a></li>
#     <li><a href="#Question_5"><b>Question 5:Display  validation dataset  object</b> </a></li>
#
# </ul>
# <p>Estimated Time Needed: <strong>25 min</strong></p>
#  </div>
# <hr>

# %% [markdown]
# <h2 id="auxiliary">Imports and Auxiliary Functions</h2>

# %% [markdown]
# The following are the libraries we are going to use for this lab:

# %%
# !pip install skillsnetwork
# Out:
# Collecting skillsnetwork
#   Downloading skillsnetwork-0.20.6-py3-none-any.whl (26 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from skillsnetwork) (7.34.0)
# Requirement already satisfied: ipywidgets<8,>=7 in /usr/local/lib/python3.10/dist-packages (from skillsnetwork) (7.7.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from skillsnetwork) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4 in /usr/local/lib/python3.10/dist-packages (from skillsnetwork) (4.66.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->skillsnetwork) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->skillsnetwork) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->skillsnetwork) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->skillsnetwork) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->skillsnetwork) (3.0.9)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->skillsnetwork) (67.7.2)
# Collecting jedi>=0.16 (from ipython->skillsnetwork)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 25.6 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->skillsnetwork) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->skillsnetwork) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->skillsnetwork) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->skillsnetwork) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->skillsnetwork) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->skillsnetwork) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->skillsnetwork) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->skillsnetwork) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->skillsnetwork) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->skillsnetwork) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->skillsnetwork) (2023.7.22)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork) (6.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->skillsnetwork) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->skillsnetwork) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->skillsnetwork) (0.2.8)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (6.5.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (3.1.2)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (5.3.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (1.5.8)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (3.11.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (0.2.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (2.1.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (0.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (23.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (2.18.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (4.19.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.1->jupyter-client->ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork) (1.16.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (0.10.4)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (1.6.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (1.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->skillsnetwork) (2.21)
# Installing collected packages: jedi, skillsnetwork
# Successfully installed jedi-0.19.1 skillsnetwork-0.20.6

# %%
from PIL import Image
import matplotlib.pyplot as plt
import os
import glob
import torch
from torch.utils.data import Dataset
import skillsnetwork
import shutil
import urllib

# %% [markdown]
# We will use this function in the lab to plot:

# %%
def show_data(data_sample, shape = (28, 28)):
    plt.imshow(data_sample[0].numpy().reshape(shape), cmap='gray')
    plt.title('y = ' + data_sample[1])

# %% [markdown]
# <h2 id="download_data">Download Data</h2>

# %% [markdown]
# In this section, you are going to download the data from IBM object storage using **skillsnetwork.prepare** command. <b>skillsnetwork.prepare</b> is a command that's used to download a zip file, unzip it and store it in a specified directory. Locally we store the data in the directory  **/resources/data**.

# %%
await skillsnetwork.prepare("https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/concrete_crack_images_for_classification.zip", path = "/resources/data", overwrite=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-44-3feb12680e30> in <cell line: 1>()
# ----> 1 await skillsnetwork.prepare("https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/concrete_crack_images_for_classification.zip", path = "/resources/data", overwrite=True)
#
# /usr/local/lib/python3.10/dist-packages/skillsnetwork/core.py in prepare(url, path, verbose, overwrite)
#     237         raise ValueError("Datasets must be prepared to directories, not files.")
#     238     # Create the target path if it doesn't exist yet
# --> 239     path.mkdir(exist_ok=True)
#     240
#     241     # For avoiding collisions with any other files the user may have downloaded to /tmp/
#
# /usr/lib/python3.10/pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1173         """
#    1174         try:
# -> 1175             self._accessor.mkdir(self, mode)
#    1176         except FileNotFoundError:
#    1177             if not parents or self.parent == self:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/resources/data'

# %%
url = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/concrete_crack_images_for_classification.zip"
headers_1 = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36'}

# Outputs
output_path = "MyFile.zip"
# request the file from website
req = urllib.request.Request(url, headers=headers_1)

# open it in a file and write it to save it in local
with urllib.request.urlopen(req) as response, open(output_path, 'wb') as f:
    shutil.copyfileobj(response, f)

# %%
print("✅ ZIP downloaded on:", output_path)
# Out:
# ✅ ZIP downloaded on: MyFile.zip

# %%
# importing the zipfile module
from zipfile import ZipFile

# loading the temp.zip and creating a zip object
with ZipFile("/content/MyFile.zip", 'r') as zObject:

	# Extracting all the members of the zip
	# into a specific location.
	zObject.extractall(
		path="/content/")

# %% [markdown]
# We then download the files that contain the negative images:

# %% [markdown]
# <h2 id="examine_files">Examine Files </h2>

# %% [markdown]
# In the previous lab, we create two lists; one to hold the path to the Negative files and one to hold the path to the Positive files. This process is shown in the following few lines of code.

# %% [markdown]
# We can obtain the list that contains the path to the <b>negative files</b> as follows:

# %%
directory="/content/"
negative='Negative'
negative_file_path=os.path.join(directory,negative)
negative_files=[os.path.join(negative_file_path,file) for file in  os.listdir(negative_file_path) if file.endswith(".jpg")]
negative_files.sort()
negative_files[0:3]
# Out:
# ['/content/Negative/00001.jpg',
#  '/content/Negative/00002.jpg',
#  '/content/Negative/00003.jpg']

# %% [markdown]
# We can obtain the list that contains the path to the <b>positive files</b> files as follows:

# %%
positive="Positive"
positive_file_path=os.path.join(directory,positive)
positive_files=[os.path.join(positive_file_path,file) for file in  os.listdir(positive_file_path) if file.endswith(".jpg")]
positive_files.sort()
positive_files[0:3]
# Out:
# ['/content/Positive/00001.jpg',
#  '/content/Positive/00002.jpg',
#  '/content/Positive/00003.jpg']

# %% [markdown]
# <h2 id="Question_1">Question 1</h2>
# <b>Find the <b>combined</b> length of the list <code>positive_files</code> and <code>negative_files</code> using the function <code>len</code> . Then assign  it to the variable <code>number_of_samples</code></b>

# %%
number_of_samples=len(positive_files)+len(negative_files)
number_of_samples
# Out:
# 40000

# %% [markdown]
# <h2 id="assign_labels">Assign Labels to Images </h2>

# %% [markdown]
# In this section we will assign a label to each image in this case we  can assign the positive images, i.e images with a crack to a value one  and the negative images i.e images with out a crack to a value of zero <b>Y</b>. First we create a tensor or vector of zeros, each element corresponds to a new sample. The length of the tensor is equal to the number of samples.

# %%
Y=torch.zeros([number_of_samples])

# %% [markdown]
# As we are using the tensor <b>Y</b> for classification we cast it to a <code>LongTensor</code>.

# %%
Y=Y.type(torch.LongTensor)
Y.type()
# Out:
# 'torch.LongTensor'

# %% [markdown]
# With respect to each element we will set the even elements to class one and the odd elements to class zero.

# %%
Y[::2]=1
Y[1::2]=0

# %% [markdown]
# <h2 id="Question_2">Question 2</h2>
# <b>Create a list all_files such that the even indexes contain the path to images with positive or cracked samples and the odd element contain the negative images or images with out cracks. Then use the following code to print out the first four samples.</b>

# %%
data=negative_files + positive_files
all_files = data.copy()
all_files[::2]= positive_files
all_files[1::2]= negative_files
all_files
# Out:
# ['/content/Positive/00001.jpg',
#  '/content/Negative/00001.jpg',
#  '/content/Positive/00002.jpg',
#  '/content/Negative/00002.jpg',
#  '/content/Positive/00003.jpg',
#  '/content/Negative/00003.jpg',
#  '/content/Positive/00004.jpg',
#  '/content/Negative/00004.jpg',
#  '/content/Positive/00005.jpg',
#  '/content/Negative/00005.jpg',
#  '/content/Positive/00006.jpg',
#  '/content/Negative/00006.jpg',
#  '/content/Positive/00007.jpg',
#  '/content/Negative/00007.jpg',
#  '/content/Positive/00008.jpg',
#  '/content/Negative/00008.jpg',
#  '/content/Positive/00009.jpg',
#  '/content/Negative/00009.jpg',
#  '/content/Positive/00010.jpg',
#  '/content/Negative/00010.jpg',
#  '/content/Positive/00011.jpg',
#  '/content/Negative/00011.jpg',
#  '/content/Positive/00012.jpg',
#  '/content/Negative/00012.jpg',
#  '/content/Positive/00013.jpg',
#  '/content/Negative/00013.jpg',
#  '/content/Positive/00014.jpg',
#  '/content/Negative/00014.jpg',
#  '/content/Positive/00015.jpg',
#  '/content/Negative/00015.jpg',
#  '/content/Positive/00016.jpg',
#  '/content/Negative/00016.jpg',
#  '/content/Positive/00017.jpg',
#  '/content/Negative/00017.jpg',
#  '/content/Positive/00018.jpg',
#  '/content/Negative/00018.jpg',
#  '/content/Positive/00019.jpg',
#  '/content/Negative/00019.jpg',
#  '/content/Positive/00020.jpg',
#  '/content/Negative/00020.jpg',
#  '/content/Positive/00021.jpg',
#  '/content/Negative/00021.jpg',
#  '/content/Positive/00022.jpg',
#  '/content/Negative/00022.jpg',
#  '/content/Positive/00023.jpg',
#  '/content/Negative/00023.jpg',
#  '/content/Positive/00024.jpg',
#  '/content/Negative/00024.jpg',
#  '/content/Positive/00025.jpg',
#  '/content/Negative/00025.jpg',
#  '/content/Positive/00026.jpg',
#  '/content/Negative/00026.jpg',
#  '/content/Positive/00027.jpg',
#  '/content/Negative/00027.jpg',
#  '/content/Positive/00028.jpg',
#  '/content/Negative/00028.jpg',
#  '/content/Positive/00029.jpg',
#  '/content/Negative/00029.jpg',
#  '/content/Positive/00030.jpg',
#  '/content/Negative/00030.jpg',
#  '/content/Positive/00031.jpg',
#  '/content/Negative/00031.jpg',
#  '/content/Positive/00032.jpg',
#  '/content/Negative/00032.jpg',
#  '/content/Positive/00033.jpg',
#  '/content/Negative/00033.jpg',
#  '/content/Positive/00034.jpg',
#  '/content/Negative/00034.jpg',
#  '/content/Positive/00035.jpg',
#  '/content/Negative/00035.jpg',
#  '/content/Positive/00036.jpg',
#  '/content/Negative/00036.jpg',
#  '/content/Positive/00037.jpg',
#  '/content/Negative/00037.jpg',
#  '/content/Positive/00038.jpg',
#  '/content/Negative/00038.jpg',
#  '/content/Positive/00039.jpg',
#  '/content/Negative/00039.jpg',
#  '/content/Positive/00040.jpg',
#  '/content/Negative/00040.jpg',
#  '/content/Positive/00041.jpg',
#  '/content/Negative/00041.jpg',
#  '/content/Positive/00042.jpg',
#  '/content/Negative/00042.jpg',
#  '/content/Positive/00043.jpg',
#  '/content/Negative/00043.jpg',
#  '/content/Positive/00044.jpg',
#  '/content/Negative/00044.jpg',
#  '/content/Positive/00045.jpg',
#  '/content/Negative/00045.jpg',
#  '/content/Positive/00046.jpg',
#  '/content/Negative/00046.jpg',
#  '/content/Positive/00047.jpg',
#  '/content/Negative/00047.jpg',
#  '/content/Positive/00048.jpg',
#  '/content/Negative/00048.jpg',
#  '/content/Positive/00049.jpg',
#  '/content/Negative/00049.jpg',
#  '/content/Positive/00050.jpg',
#  '/content/Negative/00050.jpg',
#  '/content/Positive/00051.jpg',
#  '/content/Negative/00051.jpg',
#  '/content/Positive/00052.jpg',
#  '/content/Negative/00052.jpg',
#  '/content/Positive/00053.jpg',
#  '/content/Negative/00053.jpg',
#  '/content/Positive/00054.jpg',
#  '/content/Negative/00054.jpg',
#  '/content/Positive/00055.jpg',
#  '/content/Negative/00055.jpg',
#  '/content/Positive/00056.jpg',
#  '/content/Negative/00056.jpg',
#  '/content/Positive/00057.jpg',
#  '/content/Negative/00057.jpg',
#  '/content/Positive/00058.jpg',
#  '/content/Negative/00058.jpg',
#  '/content/Positive/00059.jpg',
#  '/content/Negative/00059.jpg',
#  '/content/Positive/00060.jpg',
#  '/content/Negative/00060.jpg',
#  '/content/Positive/00061.jpg',
#  '/content/Negative/00061.jpg',
#  '/content/Positive/00062.jpg',
#  '/content/Negative/00062.jpg',
#  '/content/Positive/00063.jpg',
#  '/content/Negative/00063.jpg',
#  '/content/Positive/00064.jpg',
#  '/content/Negative/00064.jpg',
#  '/content/Positive/00065.jpg',
#  '/content/Negative/00065.jpg',
#  '/content/Positive/00066.jpg',
#  '/content/Negative/00066.jpg',
#  '/content/Positive/00067.jpg',
#  '/content/Negative/00067.jpg',
#  '/content/Positive/00068.jpg',
#  '/content/Negative/00068.jpg',
#  '/content/Positive/00069.jpg',
#  '/content/Negative/00069.jpg',
#  '/content/Positive/00070.jpg',
#  '/content/Negative/00070.jpg',
#  '/content/Positive/00071.jpg',
#  '/content/Negative/00071.jpg',
#  '/content/Positive/00072.jpg',
#  '/content/Negative/00072.jpg',
#  '/content/Positive/00073.jpg',
#  '/content/Negative/00073.jpg',
#  '/content/Positive/00074.jpg',
#  '/content/Negative/00074.jpg',
#  '/content/Positive/00075.jpg',
#  '/content/Negative/00075.jpg',
#  '/content/Positive/00076.jpg',
#  '/content/Negative/00076.jpg',
#  '/content/Positive/00077.jpg',
#  '/content/Negative/00077.jpg',
#  '/content/Positive/00078.jpg',
#  '/content/Negative/00078.jpg',
#  '/content/Positive/00079.jpg',
#  '/content/Negative/00079.jpg',
#  '/content/Positive/00080.jpg',
#  '/content/Negative/00080.jpg',
#  '/content/Positive/00081.jpg',
#  '/content/Negative/00081.jpg',
#  '/content/Positive/00082.jpg',
#  '/content/Negative/00082.jpg',
#  '/content/Positive/00083.jpg',
#  '/content/Negative/00083.jpg',
#  '/content/Positive/00084.jpg',
#  '/content/Negative/00084.jpg',
#  '/content/Positive/00085.jpg',
#  '/content/Negative/00085.jpg',
#  '/content/Positive/00086.jpg',
#  '/content/Negative/00086.jpg',
#  '/content/Positive/00087.jpg',
#  '/content/Negative/00087.jpg',
#  '/content/Positive/00088.jpg',
#  '/content/Negative/00088.jpg',
#  '/content/Positive/00089.jpg',
#  '/content/Negative/00089.jpg',
#  '/content/Positive/00090.jpg',
#  '/content/Negative/00090.jpg',
#  '/content/Positive/00091.jpg',
#  '/content/Negative/00091.jpg',
#  '/content/Positive/00092.jpg',
#  '/content/Negative/00092.jpg',
#  '/content/Positive/00093.jpg',
#  '/content/Negative/00093.jpg',
#  '/content/Positive/00094.jpg',
#  '/content/Negative/00094.jpg',
#  '/content/Positive/00095.jpg',
#  '/content/Negative/00095.jpg',
#  '/content/Positive/00096.jpg',
#  '/content/Negative/00096.jpg',
#  '/content/Positive/00097.jpg',
#  '/content/Negative/00097.jpg',
#  '/content/Positive/00098.jpg',
#  '/content/Negative/00098.jpg',
#  '/content/Positive/00099.jpg',
#  '/content/Negative/00099.jpg',
#  '/content/Positive/00100.jpg',
#  '/content/Negative/00100.jpg',
#  '/content/Positive/00101.jpg',
#  '/content/Negative/00101.jpg',
#  '/content/Positive/00102.jpg',
#  '/content/Negative/00102.jpg',
#  '/content/Positive/00103.jpg',
#  '/content/Negative/00103.jpg',
#  '/content/Positive/00104.jpg',
#  '/content/Negative/00104.jpg',
#  '/content/Positive/00105.jpg',
#  '/content/Negative/00105.jpg',
#  '/content/Positive/00106.jpg',
#  '/content/Negative/00106.jpg',
#  '/content/Positive/00107.jpg',
#  '/content/Negative/00107.jpg',
#  '/content/Positive/00108.jpg',
#  '/content/Negative/00108.jpg',
#  '/content/Positive/00109.jpg',
#  '/content/Negative/00109.jpg',
#  '/content/Positive/00110.jpg',
#  '/content/Negative/00110.jpg',
#  '/content/Positive/00111.jpg',
#  '/content/Negative/00111.jpg',
#  '/content/Positive/00112.jpg',
#  '/content/Negative/00112.jpg',
#  '/content/Positive/00113.jpg',
#  '/content/Negative/00113.jpg',
#  '/content/Positive/00114.jpg',
#  '/content/Negative/00114.jpg',
#  '/content/Positive/00115.jpg',
#  '/content/Negative/00115.jpg',
#  '/content/Positive/00116.jpg',
#  '/content/Negative/00116.jpg',
#  '/content/Positive/00117.jpg',
#  '/content/Negative/00117.jpg',
#  '/content/Positive/00118.jpg',
#  '/content/Negative/00118.jpg',
#  '/content/Positive/00119.jpg',
#  '/content/Negative/00119.jpg',
#  '/content/Positive/00120.jpg',
#  '/content/Negative/00120.jpg',
#  '/content/Positive/00121.jpg',
#  '/content/Negative/00121.jpg',
#  '/content/Positive/00122.jpg',
#  '/content/Negative/00122.jpg',
#  '/content/Positive/00123.jpg',
#  '/content/Negative/00123.jpg',
#  '/content/Positive/00124.jpg',
#  '/content/Negative/00124.jpg',
#  '/content/Positive/00125.jpg',
#  '/content/Negative/00125.jpg',
#  '/content/Positive/00126.jpg',
#  '/content/Negative/00126.jpg',
#  '/content/Positive/00127.jpg',
#  '/content/Negative/00127.jpg',
#  '/content/Positive/00128.jpg',
#  '/content/Negative/00128.jpg',
#  '/content/Positive/00129.jpg',
#  '/content/Negative/00129.jpg',
#  '/content/Positive/00130.jpg',
#  '/content/Negative/00130.jpg',
#  '/content/Positive/00131.jpg',
#  '/content/Negative/00131.jpg',
#  '/content/Positive/00132.jpg',
#  '/content/Negative/00132.jpg',
#  '/content/Positive/00133.jpg',
#  '/content/Negative/00133.jpg',
#  '/content/Positive/00134.jpg',
#  '/content/Negative/00134.jpg',
#  '/content/Positive/00135.jpg',
#  '/content/Negative/00135.jpg',
#  '/content/Positive/00136.jpg',
#  '/content/Negative/00136.jpg',
#  '/content/Positive/00137.jpg',
#  '/content/Negative/00137.jpg',
#  '/content/Positive/00138.jpg',
#  '/content/Negative/00138.jpg',
#  '/content/Positive/00139.jpg',
#  '/content/Negative/00139.jpg',
#  '/content/Positive/00140.jpg',
#  '/content/Negative/00140.jpg',
#  '/content/Positive/00141.jpg',
#  '/content/Negative/00141.jpg',
#  '/content/Positive/00142.jpg',
#  '/content/Negative/00142.jpg',
#  '/content/Positive/00143.jpg',
#  '/content/Negative/00143.jpg',
#  '/content/Positive/00144.jpg',
#  '/content/Negative/00144.jpg',
#  '/content/Positive/00145.jpg',
#  '/content/Negative/00145.jpg',
#  '/content/Positive/00146.jpg',
#  '/content/Negative/00146.jpg',
#  '/content/Positive/00147.jpg',
#  '/content/Negative/00147.jpg',
#  '/content/Positive/00148.jpg',
#  '/content/Negative/00148.jpg',
#  '/content/Positive/00149.jpg',
#  '/content/Negative/00149.jpg',
#  '/content/Positive/00150.jpg',
#  '/content/Negative/00150.jpg',
#  '/content/Positive/00151.jpg',
#  '/content/Negative/00151.jpg',
#  '/content/Positive/00152.jpg',
#  '/content/Negative/00152.jpg',
#  '/content/Positive/00153.jpg',
#  '/content/Negative/00153.jpg',
#  '/content/Positive/00154.jpg',
#  '/content/Negative/00154.jpg',
#  '/content/Positive/00155.jpg',
#  '/content/Negative/00155.jpg',
#  '/content/Positive/00156.jpg',
#  '/content/Negative/00156.jpg',
#  '/content/Positive/00157.jpg',
#  '/content/Negative/00157.jpg',
#  '/content/Positive/00158.jpg',
#  '/content/Negative/00158.jpg',
#  '/content/Positive/00159.jpg',
#  '/content/Negative/00159.jpg',
#  '/content/Positive/00160.jpg',
#  '/content/Negative/00160.jpg',
#  '/content/Positive/00161.jpg',
#  '/content/Negative/00161.jpg',
#  '/content/Positive/00162.jpg',
#  '/content/Negative/00162.jpg',
#  '/content/Positive/00163.jpg',
#  '/content/Negative/00163.jpg',
#  '/content/Positive/00164.jpg',
#  '/content/Negative/00164.jpg',
#  '/content/Positive/00165.jpg',
#  '/content/Negative/00165.jpg',
#  '/content/Positive/00166.jpg',
#  '/content/Negative/00166.jpg',
#  '/content/Positive/00167.jpg',
#  '/content/Negative/00167.jpg',
#  '/content/Positive/00168.jpg',
#  '/content/Negative/00168.jpg',
#  '/content/Positive/00169.jpg',
#  '/content/Negative/00169.jpg',
#  '/content/Positive/00170.jpg',
#  '/content/Negative/00170.jpg',
#  '/content/Positive/00171.jpg',
#  '/content/Negative/00171.jpg',
#  '/content/Positive/00172.jpg',
#  '/content/Negative/00172.jpg',
#  '/content/Positive/00173.jpg',
#  '/content/Negative/00173.jpg',
#  '/content/Positive/00174.jpg',
#  '/content/Negative/00174.jpg',
#  '/content/Positive/00175.jpg',
#  '/content/Negative/00175.jpg',
#  '/content/Positive/00176.jpg',
#  '/content/Negative/00176.jpg',
#  '/content/Positive/00177.jpg',
#  '/content/Negative/00177.jpg',
#  '/content/Positive/00178.jpg',
#  '/content/Negative/00178.jpg',
#  '/content/Positive/00179.jpg',
#  '/content/Negative/00179.jpg',
#  '/content/Positive/00180.jpg',
#  '/content/Negative/00180.jpg',
#  '/content/Positive/00181.jpg',
#  '/content/Negative/00181.jpg',
#  '/content/Positive/00182.jpg',
#  '/content/Negative/00182.jpg',
#  '/content/Positive/00183.jpg',
#  '/content/Negative/00183.jpg',
#  '/content/Positive/00184.jpg',
#  '/content/Negative/00184.jpg',
#  '/content/Positive/00185.jpg',
#  '/content/Negative/00185.jpg',
#  '/content/Positive/00186.jpg',
#  '/content/Negative/00186.jpg',
#  '/content/Positive/00187.jpg',
#  '/content/Negative/00187.jpg',
#  '/content/Positive/00188.jpg',
#  '/content/Negative/00188.jpg',
#  '/content/Positive/00189.jpg',
#  '/content/Negative/00189.jpg',
#  '/content/Positive/00190.jpg',
#  '/content/Negative/00190.jpg',
#  '/content/Positive/00191.jpg',
#  '/content/Negative/00191.jpg',
#  '/content/Positive/00192.jpg',
#  '/content/Negative/00192.jpg',
#  '/content/Positive/00193.jpg',
#  '/content/Negative/00193.jpg',
#  '/content/Positive/00194.jpg',
#  '/content/Negative/00194.jpg',
#  '/content/Positive/00195.jpg',
#  '/content/Negative/00195.jpg',
#  '/content/Positive/00196.jpg',
#  '/content/Negative/00196.jpg',
#  '/content/Positive/00197.jpg',
#  '/content/Negative/00197.jpg',
#  '/content/Positive/00198.jpg',
#  '/content/Negative/00198.jpg',
#  '/content/Positive/00199.jpg',
#  '/content/Negative/00199.jpg',
#  '/content/Positive/00200.jpg',
#  '/content/Negative/00200.jpg',
#  '/content/Positive/00201.jpg',
#  '/content/Negative/00201.jpg',
#  '/content/Positive/00202.jpg',
#  '/content/Negative/00202.jpg',
#  '/content/Positive/00203.jpg',
#  '/content/Negative/00203.jpg',
#  '/content/Positive/00204.jpg',
#  '/content/Negative/00204.jpg',
#  '/content/Positive/00205.jpg',
#  '/content/Negative/00205.jpg',
#  '/content/Positive/00206.jpg',
#  '/content/Negative/00206.jpg',
#  '/content/Positive/00207.jpg',
#  '/content/Negative/00207.jpg',
#  '/content/Positive/00208.jpg',
#  '/content/Negative/00208.jpg',
#  '/content/Positive/00209.jpg',
#  '/content/Negative/00209.jpg',
#  '/content/Positive/00210.jpg',
#  '/content/Negative/00210.jpg',
#  '/content/Positive/00211.jpg',
#  '/content/Negative/00211.jpg',
#  '/content/Positive/00212.jpg',
#  '/content/Negative/00212.jpg',
#  '/content/Positive/00213.jpg',
#  '/content/Negative/00213.jpg',
#  '/content/Positive/00214.jpg',
#  '/content/Negative/00214.jpg',
#  '/content/Positive/00215.jpg',
#  '/content/Negative/00215.jpg',
#  '/content/Positive/00216.jpg',
#  '/content/Negative/00216.jpg',
#  '/content/Positive/00217.jpg',
#  '/content/Negative/00217.jpg',
#  '/content/Positive/00218.jpg',
#  '/content/Negative/00218.jpg',
#  '/content/Positive/00219.jpg',
#  '/content/Negative/00219.jpg',
#  '/content/Positive/00220.jpg',
#  '/content/Negative/00220.jpg',
#  '/content/Positive/00221.jpg',
#  '/content/Negative/00221.jpg',
#  '/content/Positive/00222.jpg',
#  '/content/Negative/00222.jpg',
#  '/content/Positive/00223.jpg',
#  '/content/Negative/00223.jpg',
#  '/content/Positive/00224.jpg',
#  '/content/Negative/00224.jpg',
#  '/content/Positive/00225.jpg',
#  '/content/Negative/00225.jpg',
#  '/content/Positive/00226.jpg',
#  '/content/Negative/00226.jpg',
#  '/content/Positive/00227.jpg',
#  '/content/Negative/00227.jpg',
#  '/content/Positive/00228.jpg',
#  '/content/Negative/00228.jpg',
#  '/content/Positive/00229.jpg',
#  '/content/Negative/00229.jpg',
#  '/content/Positive/00230.jpg',
#  '/content/Negative/00230.jpg',
#  '/content/Positive/00231.jpg',
#  '/content/Negative/00231.jpg',
#  '/content/Positive/00232.jpg',
#  '/content/Negative/00232.jpg',
#  '/content/Positive/00233.jpg',
#  '/content/Negative/00233.jpg',
#  '/content/Positive/00234.jpg',
#  '/content/Negative/00234.jpg',
#  '/content/Positive/00235.jpg',
#  '/content/Negative/00235.jpg',
#  '/content/Positive/00236.jpg',
#  '/content/Negative/00236.jpg',
#  '/content/Positive/00237.jpg',
#  '/content/Negative/00237.jpg',
#  '/content/Positive/00238.jpg',
#  '/content/Negative/00238.jpg',
#  '/content/Positive/00239.jpg',
#  '/content/Negative/00239.jpg',
#  '/content/Positive/00240.jpg',
#  '/content/Negative/00240.jpg',
#  '/content/Positive/00241.jpg',
#  '/content/Negative/00241.jpg',
#  '/content/Positive/00242.jpg',
#  '/content/Negative/00242.jpg',
#  '/content/Positive/00243.jpg',
#  '/content/Negative/00243.jpg',
#  '/content/Positive/00244.jpg',
#  '/content/Negative/00244.jpg',
#  '/content/Positive/00245.jpg',
#  '/content/Negative/00245.jpg',
#  '/content/Positive/00246.jpg',
#  '/content/Negative/00246.jpg',
#  '/content/Positive/00247.jpg',
#  '/content/Negative/00247.jpg',
#  '/content/Positive/00248.jpg',
#  '/content/Negative/00248.jpg',
#  '/content/Positive/00249.jpg',
#  '/content/Negative/00249.jpg',
#  '/content/Positive/00250.jpg',
#  '/content/Negative/00250.jpg',
#  '/content/Positive/00251.jpg',
#  '/content/Negative/00251.jpg',
#  '/content/Positive/00252.jpg',
#  '/content/Negative/00252.jpg',
#  '/content/Positive/00253.jpg',
#  '/content/Negative/00253.jpg',
#  '/content/Positive/00254.jpg',
#  '/content/Negative/00254.jpg',
#  '/content/Positive/00255.jpg',
#  '/content/Negative/00255.jpg',
#  '/content/Positive/00256.jpg',
#  '/content/Negative/00256.jpg',
#  '/content/Positive/00257.jpg',
#  '/content/Negative/00257.jpg',
#  '/content/Positive/00258.jpg',
#  '/content/Negative/00258.jpg',
#  '/content/Positive/00259.jpg',
#  '/content/Negative/00259.jpg',
#  '/content/Positive/00260.jpg',
#  '/content/Negative/00260.jpg',
#  '/content/Positive/00261.jpg',
#  '/content/Negative/00261.jpg',
#  '/content/Positive/00262.jpg',
#  '/content/Negative/00262.jpg',
#  '/content/Positive/00263.jpg',
#  '/content/Negative/00263.jpg',
#  '/content/Positive/00264.jpg',
#  '/content/Negative/00264.jpg',
#  '/content/Positive/00265.jpg',
#  '/content/Negative/00265.jpg',
#  '/content/Positive/00266.jpg',
#  '/content/Negative/00266.jpg',
#  '/content/Positive/00267.jpg',
#  '/content/Negative/00267.jpg',
#  '/content/Positive/00268.jpg',
#  '/content/Negative/00268.jpg',
#  '/content/Positive/00269.jpg',
#  '/content/Negative/00269.jpg',
#  '/content/Positive/00270.jpg',
#  '/content/Negative/00270.jpg',
#  '/content/Positive/00271.jpg',
#  '/content/Negative/00271.jpg',
#  '/content/Positive/00272.jpg',
#  '/content/Negative/00272.jpg',
#  '/content/Positive/00273.jpg',
#  '/content/Negative/00273.jpg',
#  '/content/Positive/00274.jpg',
#  '/content/Negative/00274.jpg',
#  '/content/Positive/00275.jpg',
#  '/content/Negative/00275.jpg',
#  '/content/Positive/00276.jpg',
#  '/content/Negative/00276.jpg',
#  '/content/Positive/00277.jpg',
#  '/content/Negative/00277.jpg',
#  '/content/Positive/00278.jpg',
#  '/content/Negative/00278.jpg',
#  '/content/Positive/00279.jpg',
#  '/content/Negative/00279.jpg',
#  '/content/Positive/00280.jpg',
#  '/content/Negative/00280.jpg',
#  '/content/Positive/00281.jpg',
#  '/content/Negative/00281.jpg',
#  '/content/Positive/00282.jpg',
#  '/content/Negative/00282.jpg',
#  '/content/Positive/00283.jpg',
#  '/content/Negative/00283.jpg',
#  '/content/Positive/00284.jpg',
#  '/content/Negative/00284.jpg',
#  '/content/Positive/00285.jpg',
#  '/content/Negative/00285.jpg',
#  '/content/Positive/00286.jpg',
#  '/content/Negative/00286.jpg',
#  '/content/Positive/00287.jpg',
#  '/content/Negative/00287.jpg',
#  '/content/Positive/00288.jpg',
#  '/content/Negative/00288.jpg',
#  '/content/Positive/00289.jpg',
#  '/content/Negative/00289.jpg',
#  '/content/Positive/00290.jpg',
#  '/content/Negative/00290.jpg',
#  '/content/Positive/00291.jpg',
#  '/content/Negative/00291.jpg',
#  '/content/Positive/00292.jpg',
#  '/content/Negative/00292.jpg',
#  '/content/Positive/00293.jpg',
#  '/content/Negative/00293.jpg',
#  '/content/Positive/00294.jpg',
#  '/content/Negative/00294.jpg',
#  '/content/Positive/00295.jpg',
#  '/content/Negative/00295.jpg',
#  '/content/Positive/00296.jpg',
#  '/content/Negative/00296.jpg',
#  '/content/Positive/00297.jpg',
#  '/content/Negative/00297.jpg',
#  '/content/Positive/00298.jpg',
#  '/content/Negative/00298.jpg',
#  '/content/Positive/00299.jpg',
#  '/content/Negative/00299.jpg',
#  '/content/Positive/00300.jpg',
#  '/content/Negative/00300.jpg',
#  '/content/Positive/00301.jpg',
#  '/content/Negative/00301.jpg',
#  '/content/Positive/00302.jpg',
#  '/content/Negative/00302.jpg',
#  '/content/Positive/00303.jpg',
#  '/content/Negative/00303.jpg',
#  '/content/Positive/00304.jpg',
#  '/content/Negative/00304.jpg',
#  '/content/Positive/00305.jpg',
#  '/content/Negative/00305.jpg',
#  '/content/Positive/00306.jpg',
#  '/content/Negative/00306.jpg',
#  '/content/Positive/00307.jpg',
#  '/content/Negative/00307.jpg',
#  '/content/Positive/00308.jpg',
#  '/content/Negative/00308.jpg',
#  '/content/Positive/00309.jpg',
#  '/content/Negative/00309.jpg',
#  '/content/Positive/00310.jpg',
#  '/content/Negative/00310.jpg',
#  '/content/Positive/00311.jpg',
#  '/content/Negative/00311.jpg',
#  '/content/Positive/00312.jpg',
#  '/content/Negative/00312.jpg',
#  '/content/Positive/00313.jpg',
#  '/content/Negative/00313.jpg',
#  '/content/Positive/00314.jpg',
#  '/content/Negative/00314.jpg',
#  '/content/Positive/00315.jpg',
#  '/content/Negative/00315.jpg',
#  '/content/Positive/00316.jpg',
#  '/content/Negative/00316.jpg',
#  '/content/Positive/00317.jpg',
#  '/content/Negative/00317.jpg',
#  '/content/Positive/00318.jpg',
#  '/content/Negative/00318.jpg',
#  '/content/Positive/00319.jpg',
#  '/content/Negative/00319.jpg',
#  '/content/Positive/00320.jpg',
#  '/content/Negative/00320.jpg',
#  '/content/Positive/00321.jpg',
#  '/content/Negative/00321.jpg',
#  '/content/Positive/00322.jpg',
#  '/content/Negative/00322.jpg',
#  '/content/Positive/00323.jpg',
#  '/content/Negative/00323.jpg',
#  '/content/Positive/00324.jpg',
#  '/content/Negative/00324.jpg',
#  '/content/Positive/00325.jpg',
#  '/content/Negative/00325.jpg',
#  '/content/Positive/00326.jpg',
#  '/content/Negative/00326.jpg',
#  '/content/Positive/00327.jpg',
#  '/content/Negative/00327.jpg',
#  '/content/Positive/00328.jpg',
#  '/content/Negative/00328.jpg',
#  '/content/Positive/00329.jpg',
#  '/content/Negative/00329.jpg',
#  '/content/Positive/00330.jpg',
#  '/content/Negative/00330.jpg',
#  '/content/Positive/00331.jpg',
#  '/content/Negative/00331.jpg',
#  '/content/Positive/00332.jpg',
#  '/content/Negative/00332.jpg',
#  '/content/Positive/00333.jpg',
#  '/content/Negative/00333.jpg',
#  '/content/Positive/00334.jpg',
#  '/content/Negative/00334.jpg',
#  '/content/Positive/00335.jpg',
#  '/content/Negative/00335.jpg',
#  '/content/Positive/00336.jpg',
#  '/content/Negative/00336.jpg',
#  '/content/Positive/00337.jpg',
#  '/content/Negative/00337.jpg',
#  '/content/Positive/00338.jpg',
#  '/content/Negative/00338.jpg',
#  '/content/Positive/00339.jpg',
#  '/content/Negative/00339.jpg',
#  '/content/Positive/00340.jpg',
#  '/content/Negative/00340.jpg',
#  '/content/Positive/00341.jpg',
#  '/content/Negative/00341.jpg',
#  '/content/Positive/00342.jpg',
#  '/content/Negative/00342.jpg',
#  '/content/Positive/00343.jpg',
#  '/content/Negative/00343.jpg',
#  '/content/Positive/00344.jpg',
#  '/content/Negative/00344.jpg',
#  '/content/Positive/00345.jpg',
#  '/content/Negative/00345.jpg',
#  '/content/Positive/00346.jpg',
#  '/content/Negative/00346.jpg',
#  '/content/Positive/00347.jpg',
#  '/content/Negative/00347.jpg',
#  '/content/Positive/00348.jpg',
#  '/content/Negative/00348.jpg',
#  '/content/Positive/00349.jpg',
#  '/content/Negative/00349.jpg',
#  '/content/Positive/00350.jpg',
#  '/content/Negative/00350.jpg',
#  '/content/Positive/00351.jpg',
#  '/content/Negative/00351.jpg',
#  '/content/Positive/00352.jpg',
#  '/content/Negative/00352.jpg',
#  '/content/Positive/00353.jpg',
#  '/content/Negative/00353.jpg',
#  '/content/Positive/00354.jpg',
#  '/content/Negative/00354.jpg',
#  '/content/Positive/00355.jpg',
#  '/content/Negative/00355.jpg',
#  '/content/Positive/00356.jpg',
#  '/content/Negative/00356.jpg',
#  '/content/Positive/00357.jpg',
#  '/content/Negative/00357.jpg',
#  '/content/Positive/00358.jpg',
#  '/content/Negative/00358.jpg',
#  '/content/Positive/00359.jpg',
#  '/content/Negative/00359.jpg',
#  '/content/Positive/00360.jpg',
#  '/content/Negative/00360.jpg',
#  '/content/Positive/00361.jpg',
#  '/content/Negative/00361.jpg',
#  '/content/Positive/00362.jpg',
#  '/content/Negative/00362.jpg',
#  '/content/Positive/00363.jpg',
#  '/content/Negative/00363.jpg',
#  '/content/Positive/00364.jpg',
#  '/content/Negative/00364.jpg',
#  '/content/Positive/00365.jpg',
#  '/content/Negative/00365.jpg',
#  '/content/Positive/00366.jpg',
#  '/content/Negative/00366.jpg',
#  '/content/Positive/00367.jpg',
#  '/content/Negative/00367.jpg',
#  '/content/Positive/00368.jpg',
#  '/content/Negative/00368.jpg',
#  '/content/Positive/00369.jpg',
#  '/content/Negative/00369.jpg',
#  '/content/Positive/00370.jpg',
#  '/content/Negative/00370.jpg',
#  '/content/Positive/00371.jpg',
#  '/content/Negative/00371.jpg',
#  '/content/Positive/00372.jpg',
#  '/content/Negative/00372.jpg',
#  '/content/Positive/00373.jpg',
#  '/content/Negative/00373.jpg',
#  '/content/Positive/00374.jpg',
#  '/content/Negative/00374.jpg',
#  '/content/Positive/00375.jpg',
#  '/content/Negative/00375.jpg',
#  '/content/Positive/00376.jpg',
#  '/content/Negative/00376.jpg',
#  '/content/Positive/00377.jpg',
#  '/content/Negative/00377.jpg',
#  '/content/Positive/00378.jpg',
#  '/content/Negative/00378.jpg',
#  '/content/Positive/00379.jpg',
#  '/content/Negative/00379.jpg',
#  '/content/Positive/00380.jpg',
#  '/content/Negative/00380.jpg',
#  '/content/Positive/00381.jpg',
#  '/content/Negative/00381.jpg',
#  '/content/Positive/00382.jpg',
#  '/content/Negative/00382.jpg',
#  '/content/Positive/00383.jpg',
#  '/content/Negative/00383.jpg',
#  '/content/Positive/00384.jpg',
#  '/content/Negative/00384.jpg',
#  '/content/Positive/00385.jpg',
#  '/content/Negative/00385.jpg',
#  '/content/Positive/00386.jpg',
#  '/content/Negative/00386.jpg',
#  '/content/Positive/00387.jpg',
#  '/content/Negative/00387.jpg',
#  '/content/Positive/00388.jpg',
#  '/content/Negative/00388.jpg',
#  '/content/Positive/00389.jpg',
#  '/content/Negative/00389.jpg',
#  '/content/Positive/00390.jpg',
#  '/content/Negative/00390.jpg',
#  '/content/Positive/00391.jpg',
#  '/content/Negative/00391.jpg',
#  '/content/Positive/00392.jpg',
#  '/content/Negative/00392.jpg',
#  '/content/Positive/00393.jpg',
#  '/content/Negative/00393.jpg',
#  '/content/Positive/00394.jpg',
#  '/content/Negative/00394.jpg',
#  '/content/Positive/00395.jpg',
#  '/content/Negative/00395.jpg',
#  '/content/Positive/00396.jpg',
#  '/content/Negative/00396.jpg',
#  '/content/Positive/00397.jpg',
#  '/content/Negative/00397.jpg',
#  '/content/Positive/00398.jpg',
#  '/content/Negative/00398.jpg',
#  '/content/Positive/00399.jpg',
#  '/content/Negative/00399.jpg',
#  '/content/Positive/00400.jpg',
#  '/content/Negative/00400.jpg',
#  '/content/Positive/00401.jpg',
#  '/content/Negative/00401.jpg',
#  '/content/Positive/00402.jpg',
#  '/content/Negative/00402.jpg',
#  '/content/Positive/00403.jpg',
#  '/content/Negative/00403.jpg',
#  '/content/Positive/00404.jpg',
#  '/content/Negative/00404.jpg',
#  '/content/Positive/00405.jpg',
#  '/content/Negative/00405.jpg',
#  '/content/Positive/00406.jpg',
#  '/content/Negative/00406.jpg',
#  '/content/Positive/00407.jpg',
#  '/content/Negative/00407.jpg',
#  '/content/Positive/00408.jpg',
#  '/content/Negative/00408.jpg',
#  '/content/Positive/00409.jpg',
#  '/content/Negative/00409.jpg',
#  '/content/Positive/00410.jpg',
#  '/content/Negative/00410.jpg',
#  '/content/Positive/00411.jpg',
#  '/content/Negative/00411.jpg',
#  '/content/Positive/00412.jpg',
#  '/content/Negative/00412.jpg',
#  '/content/Positive/00413.jpg',
#  '/content/Negative/00413.jpg',
#  '/content/Positive/00414.jpg',
#  '/content/Negative/00414.jpg',
#  '/content/Positive/00415.jpg',
#  '/content/Negative/00415.jpg',
#  '/content/Positive/00416.jpg',
#  '/content/Negative/00416.jpg',
#  '/content/Positive/00417.jpg',
#  '/content/Negative/00417.jpg',
#  '/content/Positive/00418.jpg',
#  '/content/Negative/00418.jpg',
#  '/content/Positive/00419.jpg',
#  '/content/Negative/00419.jpg',
#  '/content/Positive/00420.jpg',
#  '/content/Negative/00420.jpg',
#  '/content/Positive/00421.jpg',
#  '/content/Negative/00421.jpg',
#  '/content/Positive/00422.jpg',
#  '/content/Negative/00422.jpg',
#  '/content/Positive/00423.jpg',
#  '/content/Negative/00423.jpg',
#  '/content/Positive/00424.jpg',
#  '/content/Negative/00424.jpg',
#  '/content/Positive/00425.jpg',
#  '/content/Negative/00425.jpg',
#  '/content/Positive/00426.jpg',
#  '/content/Negative/00426.jpg',
#  '/content/Positive/00427.jpg',
#  '/content/Negative/00427.jpg',
#  '/content/Positive/00428.jpg',
#  '/content/Negative/00428.jpg',
#  '/content/Positive/00429.jpg',
#  '/content/Negative/00429.jpg',
#  '/content/Positive/00430.jpg',
#  '/content/Negative/00430.jpg',
#  '/content/Positive/00431.jpg',
#  '/content/Negative/00431.jpg',
#  '/content/Positive/00432.jpg',
#  '/content/Negative/00432.jpg',
#  '/content/Positive/00433.jpg',
#  '/content/Negative/00433.jpg',
#  '/content/Positive/00434.jpg',
#  '/content/Negative/00434.jpg',
#  '/content/Positive/00435.jpg',
#  '/content/Negative/00435.jpg',
#  '/content/Positive/00436.jpg',
#  '/content/Negative/00436.jpg',
#  '/content/Positive/00437.jpg',
#  '/content/Negative/00437.jpg',
#  '/content/Positive/00438.jpg',
#  '/content/Negative/00438.jpg',
#  '/content/Positive/00439.jpg',
#  '/content/Negative/00439.jpg',
#  '/content/Positive/00440.jpg',
#  '/content/Negative/00440.jpg',
#  '/content/Positive/00441.jpg',
#  '/content/Negative/00441.jpg',
#  '/content/Positive/00442.jpg',
#  '/content/Negative/00442.jpg',
#  '/content/Positive/00443.jpg',
#  '/content/Negative/00443.jpg',
#  '/content/Positive/00444.jpg',
#  '/content/Negative/00444.jpg',
#  '/content/Positive/00445.jpg',
#  '/content/Negative/00445.jpg',
#  '/content/Positive/00446.jpg',
#  '/content/Negative/00446.jpg',
#  '/content/Positive/00447.jpg',
#  '/content/Negative/00447.jpg',
#  '/content/Positive/00448.jpg',
#  '/content/Negative/00448.jpg',
#  '/content/Positive/00449.jpg',
#  '/content/Negative/00449.jpg',
#  '/content/Positive/00450.jpg',
#  '/content/Negative/00450.jpg',
#  '/content/Positive/00451.jpg',
#  '/content/Negative/00451.jpg',
#  '/content/Positive/00452.jpg',
#  '/content/Negative/00452.jpg',
#  '/content/Positive/00453.jpg',
#  '/content/Negative/00453.jpg',
#  '/content/Positive/00454.jpg',
#  '/content/Negative/00454.jpg',
#  '/content/Positive/00455.jpg',
#  '/content/Negative/00455.jpg',
#  '/content/Positive/00456.jpg',
#  '/content/Negative/00456.jpg',
#  '/content/Positive/00457.jpg',
#  '/content/Negative/00457.jpg',
#  '/content/Positive/00458.jpg',
#  '/content/Negative/00458.jpg',
#  '/content/Positive/00459.jpg',
#  '/content/Negative/00459.jpg',
#  '/content/Positive/00460.jpg',
#  '/content/Negative/00460.jpg',
#  '/content/Positive/00461.jpg',
#  '/content/Negative/00461.jpg',
#  '/content/Positive/00462.jpg',
#  '/content/Negative/00462.jpg',
#  '/content/Positive/00463.jpg',
#  '/content/Negative/00463.jpg',
#  '/content/Positive/00464.jpg',
#  '/content/Negative/00464.jpg',
#  '/content/Positive/00465.jpg',
#  '/content/Negative/00465.jpg',
#  '/content/Positive/00466.jpg',
#  '/content/Negative/00466.jpg',
#  '/content/Positive/00467.jpg',
#  '/content/Negative/00467.jpg',
#  '/content/Positive/00468.jpg',
#  '/content/Negative/00468.jpg',
#  '/content/Positive/00469.jpg',
#  '/content/Negative/00469.jpg',
#  '/content/Positive/00470.jpg',
#  '/content/Negative/00470.jpg',
#  '/content/Positive/00471.jpg',
#  '/content/Negative/00471.jpg',
#  '/content/Positive/00472.jpg',
#  '/content/Negative/00472.jpg',
#  '/content/Positive/00473.jpg',
#  '/content/Negative/00473.jpg',
#  '/content/Positive/00474.jpg',
#  '/content/Negative/00474.jpg',
#  '/content/Positive/00475.jpg',
#  '/content/Negative/00475.jpg',
#  '/content/Positive/00476.jpg',
#  '/content/Negative/00476.jpg',
#  '/content/Positive/00477.jpg',
#  '/content/Negative/00477.jpg',
#  '/content/Positive/00478.jpg',
#  '/content/Negative/00478.jpg',
#  '/content/Positive/00479.jpg',
#  '/content/Negative/00479.jpg',
#  '/content/Positive/00480.jpg',
#  '/content/Negative/00480.jpg',
#  '/content/Positive/00481.jpg',
#  '/content/Negative/00481.jpg',
#  '/content/Positive/00482.jpg',
#  '/content/Negative/00482.jpg',
#  '/content/Positive/00483.jpg',
#  '/content/Negative/00483.jpg',
#  '/content/Positive/00484.jpg',
#  '/content/Negative/00484.jpg',
#  '/content/Positive/00485.jpg',
#  '/content/Negative/00485.jpg',
#  '/content/Positive/00486.jpg',
#  '/content/Negative/00486.jpg',
#  '/content/Positive/00487.jpg',
#  '/content/Negative/00487.jpg',
#  '/content/Positive/00488.jpg',
#  '/content/Negative/00488.jpg',
#  '/content/Positive/00489.jpg',
#  '/content/Negative/00489.jpg',
#  '/content/Positive/00490.jpg',
#  '/content/Negative/00490.jpg',
#  '/content/Positive/00491.jpg',
#  '/content/Negative/00491.jpg',
#  '/content/Positive/00492.jpg',
#  '/content/Negative/00492.jpg',
#  '/content/Positive/00493.jpg',
#  '/content/Negative/00493.jpg',
#  '/content/Positive/00494.jpg',
#  '/content/Negative/00494.jpg',
#  '/content/Positive/00495.jpg',
#  '/content/Negative/00495.jpg',
#  '/content/Positive/00496.jpg',
#  '/content/Negative/00496.jpg',
#  '/content/Positive/00497.jpg',
#  '/content/Negative/00497.jpg',
#  '/content/Positive/00498.jpg',
#  '/content/Negative/00498.jpg',
#  '/content/Positive/00499.jpg',
#  '/content/Negative/00499.jpg',
#  '/content/Positive/00500.jpg',
#  '/content/Negative/00500.jpg',
#  ...]

# %% [markdown]
# code used to print samples:

# %%
for y,file in zip(Y, all_files[0:4]):
    plt.imshow(Image.open(file))
    plt.title("y="+str(y.item()))
    plt.show()

# %% [markdown]
# <h2 id="split">Training  and Validation  Split  </h2>
# When training the model we  split up our data into training and validation data. It If the variable train is set to <code>True</code>  the following lines of code will segment the  tensor <b>Y</b> such at  the first 30000 samples are used for training. If the variable train is set to <code>False</code> the remainder of the samples will be used for validation data.

# %%
train=False

if train:
    all_files=all_files[0:30000]
    Y=Y[0:30000]

else:
    all_files=all_files[30000:]
    Y=Y[30000:]

# %% [markdown]
# <h2 id="Question_3">Question 3</h2>
# Modify the above lines of code such that if the variable <code>train</code> is set to <c>True</c> the first 30000 samples of all_files are use in training. If <code>train</code> is set to <code>False</code> the remaining  samples are used for validation. In both cases reassign  the values to the variable all_files, then use the following lines of code to print out the first four validation sample images.

# %%
train= True
if train:
    all_files=all_files[0:30000]
    Y=Y[0:30000]

else:
    all_files=all_files[30000:]
    Y=Y[30000:]

# %% [markdown]
# Just a note the images printed out in question two are the first four training samples.

# %% [markdown]
# <h2 id="data_class">Create a Dataset Class</h2>

# %% [markdown]
# In this section, we will use the previous code to build a dataset class.

# %% [markdown]
# Complete the code to build a Dataset class <code>dataset</code>. As before, make sure the even samples are positive, and the odd samples are negative.  If the parameter <code>train</code> is set to <code>True</code>, use the first 30 000  samples as training data; otherwise, the remaining samples will be used as validation data.

# %%
class Dataset(Dataset):

    # Constructor
    def __init__(self,transform=None,train=True):
        directory="/content/"
        positive="Positive"
        negative="Negative"

        positive_file_path=os.path.join(directory,positive)
        negative_file_path=os.path.join(directory,negative)
        positive_files=[os.path.join(positive_file_path,file) for file in  os.listdir(positive_file_path) if file.endswith(".jpg")]
        positive_files.sort()
        negative_files=[os.path.join(negative_file_path,file) for file in  os.listdir(negative_file_path) if file.endswith(".jpg")]
        negative_files.sort()

        self.all_files=[None]*number_of_samples
        self.all_files[::2]=positive_files
        self.all_files[1::2]=negative_files
        # The transform is goint to be used on image
        self.transform = transform
        #torch.LongTensor
        self.Y=torch.zeros([number_of_samples]).type(torch.LongTensor)
        self.Y[::2]=1
        self.Y[1::2]=0

        if train:

            self.Y=self.Y[0:30000]
            self.len=len(self.all_files)
        else:

            self.Y=self.Y[30000:]
            self.len=len(self.all_files)





    # Get the length
    def __len__(self):
        return self.len

    # Getter
    def __getitem__(self, idx):


        image=Image.open(self.all_files[idx])
        y=self.Y[idx]


        # If there is any transform method, apply it onto the image
        if self.transform:
            image = self.transform(image)

        return image, y

# %% [markdown]
# <h2 id="Question_4">Question 4</h2>
# <b>Create a Dataset object <code>dataset</code> for the training data, use the following lines of code to print out sample the 10th and  sample 100 (remember zero indexing)  </b>

# %%
dataset = Dataset()
dataset.__init__
# Out:
# <bound method Dataset.__init__ of <__main__.Dataset object at 0x7af5600954b0>>

# %%
samples=[9,99]
for sample  in samples:
    plt.imshow(dataset[sample][0])
    plt.xlabel("y="+str(dataset[sample][1].item()))
    plt.title("training data, sample {}".format(int(sample)))
    plt.show()

# %% [markdown]
# We now have all the tools to create a list with the path to each image file.  We use a List Comprehensions  to make the code more compact. We assign it to the variable <code>negative_files<code> , sort it in and display the first three elements:

# %% [markdown]
# <h2 id="Question_5">Question 5</h2>
# <b>Create a Dataset object <code>dataset</code> for the validation  data, use the following lines of code to print out the 16 th and  sample 103 (remember zero indexing)   </b>

# %%
samples=[15,102]
for sample  in samples:
    plt.imshow(dataset[sample][0])
    plt.xlabel("y="+str(dataset[sample][1].item()))
    plt.title("validation data, sample {}".format(int(sample)))
    plt.show()

# %% [markdown]
# <h2>About the Authors:</h2>
#  <a href=\"https://www.linkedin.com/in/joseph-s-50398b136/\">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-09-18  | 2.0  | Shubham  |  Migrated Lab to Markdown and added to course repo in GitLab |

# %% [markdown]
# Copyright &copy; 2018 <a href="cognitiveclass.ai">cognitiveclass.ai</a>. This notebook and its source code are released under the terms of the <a href=\"https://bigdatauniversity.com/mit-license/\">MIT License</a>
